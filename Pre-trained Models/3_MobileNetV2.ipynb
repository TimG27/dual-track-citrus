# %%
from google.colab import drive
import shutil
import torch
from torchvision import transforms, models
import torchvision
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch import Tensor
from typing import Optional, Sequence

# %% [markdown]
# Dataset

# %%
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
batch_size = 4

# %% [markdown]
# Loading the dataset

# %%
img_size = 256
dataset_path = '/content/gdrive/MyDrive/Train-Test-Val/'

# %%
# Transformer to tensor

transformer=transforms.Compose([
    transforms.Resize((img_size,img_size)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
])

def load_dataset(d_path):
    train_dataset_manual = torchvision.datasets.ImageFolder(d_path, transform=transformer)
    train_loader_manual = torch.utils.data.DataLoader(train_dataset_manual)
    return train_loader_manual

train_dataset = load_dataset(str(dataset_path + 'train')).dataset
test_dataset = load_dataset(str(dataset_path + 'test')).dataset
valid_dataset = load_dataset(str(dataset_path + 'val')).dataset

train_dataset = torch.utils.data.ConcatDataset ([train_dataset, test_dataset])

train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=2, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=2, shuffle=True)

train_count = len(train_dataset)
valid_count = len(valid_dataset)

print('Train Set- ' + str(len(train_dataset)) + ' images in ' + str(len(train_loader)) +' batches')
print('Validation Set - ' + str(len(valid_dataset)) + ' images in ' + str(len(valid_loader)) + ' batches')
# Out:
# Train Set- 6175 images in 1544 batches
# Validation Set - 1388 images in 347 batches

# %% [markdown]
# Network

# %%
import torchvision.models as models

# %% [markdown]
# Model

# %%
num_classes = 7

# %%
if torch.cuda.is_available():
  torch.backends.cudnn.deterministic = True

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
model= models.mobilenet_v2(pretrained=False)
model.classifier = nn.Sequential (
    nn.Dropout(p = 0.2, inplace = False),
    nn.Linear (in_features = 1280, out_features = 7, bias = True))
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
if torch.cuda.is_available():
    model.cuda()

# %% [markdown]
# Trainable Parameters

# %%
total_params = sum(p.numel() for p in model.parameters())
print ("Number of Trainable Parameters -", total_params)
# Out:
# Number of Trainable Parameters - 2232839

# %% [markdown]
# Training

# %%
num_epochs = 15
LEARNING_RATE = 0.0001
WEIGHT_DECAY = 0.0001

optimizer=optim.Adam(model.parameters(),lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)
loss_function=nn.CrossEntropyLoss()

# %%
for epoch in range(num_epochs):
    
    #Evaluation and training on training dataset
    model.train()

    train_accuracy=0.0
    train_loss=0.0
    
    for i, (images,labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
            
        optimizer.zero_grad()
        
        outputs=model(images)

        loss=loss_function(outputs,labels)
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        _,prediction=torch.max(outputs.data,1)
        
        train_accuracy+=int(torch.sum(prediction==labels.data))

        
    train_accuracy=train_accuracy/train_count
    train_loss=train_loss/train_count
    
    
    # Evaluation on validation dataset
    model.eval()
    
    valid_accuracy = 0.0
    valid_loss = 0.0

    for i, (images,labels) in enumerate(valid_loader):
        images, labels = images.to(device), labels.to(device)
            
        outputs=model(images)

        loss = loss_function (outputs, labels)
        _,prediction=torch.max(outputs.data,1)
        valid_accuracy += int(torch.sum(prediction == labels.data))
        valid_loss+= loss.item()
        
    valid_accuracy = valid_accuracy/valid_count
    valid_loss = valid_loss/valid_count
        
    print('Epoch: %d Train Accuracy: %.5f Train Loss: %.5f Validation Accuracy: %.5f  Validation Loss: %.5f' % (epoch, train_accuracy, train_loss, valid_accuracy, valid_loss))
# Out:
# Epoch: 0 Train Accuracy: 0.41749 Train Loss: 0.35779 Validation Accuracy: 0.63689  Validation Loss: 0.25591
# Epoch: 1 Train Accuracy: 0.55530 Train Loss: 0.29264 Validation Accuracy: 0.72190  Validation Loss: 0.19967
# Epoch: 2 Train Accuracy: 0.62802 Train Loss: 0.25234 Validation Accuracy: 0.74352  Validation Loss: 0.18807
# Epoch: 3 Train Accuracy: 0.66688 Train Loss: 0.22661 Validation Accuracy: 0.69236  Validation Loss: 0.25530
# Epoch: 4 Train Accuracy: 0.70089 Train Loss: 0.20689 Validation Accuracy: 0.78026  Validation Loss: 0.17527
# Epoch: 5 Train Accuracy: 0.75109 Train Loss: 0.17524 Validation Accuracy: 0.76513  Validation Loss: 0.25202
# Epoch: 6 Train Accuracy: 0.77377 Train Loss: 0.15963 Validation Accuracy: 0.77522  Validation Loss: 0.21410
# Epoch: 7 Train Accuracy: 0.80939 Train Loss: 0.13929 Validation Accuracy: 0.82853  Validation Loss: 0.13884
# Epoch: 8 Train Accuracy: 0.82526 Train Loss: 0.12301 Validation Accuracy: 0.82853  Validation Loss: 0.12063
# Epoch: 9 Train Accuracy: 0.84745 Train Loss: 0.11133 Validation Accuracy: 0.86455  Validation Loss: 0.10306
# Epoch: 10 Train Accuracy: 0.86818 Train Loss: 0.10094 Validation Accuracy: 0.89049  Validation Loss: 0.08648
# Epoch: 11 Train Accuracy: 0.87449 Train Loss: 0.09296 Validation Accuracy: 0.87608  Validation Loss: 0.08897
# Epoch: 12 Train Accuracy: 0.88729 Train Loss: 0.08707 Validation Accuracy: 0.87464  Validation Loss: 0.09782
# Epoch: 13 Train Accuracy: 0.89733 Train Loss: 0.07851 Validation Accuracy: 0.90850  Validation Loss: 0.07739
# Epoch: 14 Train Accuracy: 0.91320 Train Loss: 0.06744 Validation Accuracy: 0.89337  Validation Loss: 0.09304

# %%
#Save the model
save_path = '/content/gdrive/MyDrive/Train-Test-Val/MobNet-E15'
torch.save(model, save_path)

# %% [markdown]
# Testing

# %%
#Load latest model
save_path = '/content/gdrive/MyDrive/Train-Test-Val/MobNet-E15'
model = torch.load(save_path)

# %%
#path for testing dataset
dataset_path = '/content/gdrive/MyDrive/Train-Test-Val/test'

# %%
batch_size = 9

# %%
test_dataset = load_dataset(str(dataset_path)).dataset
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2, shuffle=False)
print('Testing Set - ' + str(len(test_dataset)) + ' images in ' + str(len(test_loader)) + ' batches' )
# Out:
# Testing Set - 2007 images in 223 batches

# %%
model.eval()

# %%
y_pred = []
y_true = []

# iterate over test data
for i, (images, labels) in enumerate(test_loader):
    images, labels = images.to(device), labels.to(device)

    output = model(images) # Feed Network

    output = (torch.max(torch.exp(output), 1)[1])
    output = output.data.cpu().numpy()

    y_pred.extend(output) # Save Prediction
        
    labels1 = labels.data.cpu().numpy()
    y_true.extend(labels1) # Save Truth
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5f708f6228aa> in <cell line: 6>()
#       4 # iterate over test data
#       5 #for inputs, labels in test_loader:
# ----> 6 for i, (images, labels) in enumerate(test_loader):
#       7     #print(i)
#       8     images, labels = images.to(device), labels.to(device)
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     632                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633                 self._reset()  # type: ignore[call-arg]
# --> 634             data = self._next_data()
#     635             self._num_yielded += 1
#     636             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1327
#    1328             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329             idx, data = self._get_data()
#    1330             self._tasks_outstanding -= 1
#    1331             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1293         else:
#    1294             while True:
# -> 1295                 success, data = self._try_get_data()
#    1296                 if success:
#    1297                     return data
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1131         #   (bool: whether successfully get data, any: data if successful else None)
#    1132         try:
# -> 1133             data = self._data_queue.get(timeout=timeout)
#    1134             return (True, data)
#    1135         except Exception as e:
#
# /usr/lib/python3.9/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.9/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.9/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# /usr/lib/python3.9/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# Metrics

# %%
from sklearn.metrics import classification_report, accuracy_score
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
r = classification_report(y_true, y_pred,zero_division=0,output_dict=True)

# %%
print ('Accuracy - ', r.get ('accuracy'))
print ('Weighted Average - ', r.get('weighted avg'))
print ('Macro Average - ', r.get('macro avg'))
# Out:
# Accuracy -  0.1111111111111111
# Weighted Average -  {'precision': 0.8735449735449735, 'recall': 0.1111111111111111, 'f1-score': 0.1828115261699222, 'support': 189}
# Macro Average -  {'precision': 0.2861111111111111, 'recall': 0.0804093567251462, 'f1-score': 0.0976051239209134, 'support': 189}

# %% [markdown]
# ROC Curve

# %%
model.eval()
y_test = []
y_score = []

# %%
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        #print (i)
        inputs, classes = inputs.to(device), classes.to(device)
        y_test.append(F.one_hot(classes.cpu(), 7).numpy())
        
        try:
            bs, ncrops, c, h, w = inputs.size()
        except:
            bs, c, h, w = inputs.size()
            ncrops = 1
        outputs = model(inputs)
        
        y_score.append(outputs.cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b5be78e57a97> in <cell line: 1>()
#       1 with torch.no_grad():
# ----> 2     for i, (inputs, classes) in enumerate(test_loader):
#       3         #print (i)
#       4         inputs, classes = inputs.to(device), classes.to(device)
#       5         y_test.append(F.one_hot(classes.cpu(), 7).numpy())
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     632                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633                 self._reset()  # type: ignore[call-arg]
# --> 634             data = self._next_data()
#     635             self._num_yielded += 1
#     636             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1327
#    1328             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329             idx, data = self._get_data()
#    1330             self._tasks_outstanding -= 1
#    1331             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1293         else:
#    1294             while True:
# -> 1295                 success, data = self._try_get_data()
#    1296                 if success:
#    1297                     return data
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1131         #   (bool: whether successfully get data, any: data if successful else None)
#    1132         try:
# -> 1133             data = self._data_queue.get(timeout=timeout)
#    1134             return (True, data)
#    1135         except Exception as e:
#
# /usr/lib/python3.9/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.9/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.9/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# /usr/lib/python3.9/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %%
y_test = np.array([t.ravel() for t in y_test], dtype='object')
y_score = np.array([t.ravel() for t in y_score], dtype='object')

# %%
y_test = y_test.astype('float')
y_score = y_score.astype('float')

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr = dict()
tpr = dict()
local_roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(np.array(y_test[:, i]),np.array(y_score[:, i]))
    local_roc_auc[i] = metrics.auc(fpr[i], tpr[i])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
local_roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(7)]))
# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(7):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# %%
# Finally average it and compute AUC
mean_tpr /= 7
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
local_roc_auc["macro"] = metrics.auc(fpr["macro"], tpr["macro"])

# %%
import matplotlib.pyplot as plt
import itertools

plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-avg ROC curve (area = {0:0.5f})'
               ''.format(local_roc_auc["micro"]),
         color='deeppink', linewidth=2)
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-avg ROC curve (area = {0:0.5f})'
               ''.format(local_roc_auc["macro"]),
         color='navy', linewidth=2)

plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.savefig('samplefigure', bbox_inches='tight')

# %% [markdown]
# AUC Values

# %%
print ("AUC - MicroAvg: ", local_roc_auc["micro"])
print ("AUC - MacroAvg: ", local_roc_auc["macro"])
# Out:
# AUC - MicroAvg:  0.6466008230452676
# AUC - MacroAvg:  nan
