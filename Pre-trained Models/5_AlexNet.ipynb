# %%
from google.colab import drive
import shutil
import torch
from torchvision import transforms, models
import torchvision
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch import Tensor
from typing import Optional, Sequence

# %% [markdown]
# Dataset

# %%
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
batch_size = 4

# %% [markdown]
# Loading the dataset

# %%
img_size = 256
dataset_path = '/content/gdrive/MyDrive/Train-Test-Val/'

# %%
# Transformer to tensor

transformer=transforms.Compose([
    transforms.Resize((img_size,img_size)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
])

def load_dataset(d_path):
    train_dataset_manual = torchvision.datasets.ImageFolder(d_path, transform=transformer)
    train_loader_manual = torch.utils.data.DataLoader(train_dataset_manual)
    return train_loader_manual

train_dataset = load_dataset(str(dataset_path + 'train')).dataset
test_dataset = load_dataset(str(dataset_path + 'test')).dataset
valid_dataset = load_dataset(str(dataset_path + 'val')).dataset

train_dataset = torch.utils.data.ConcatDataset ([train_dataset, test_dataset])

train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=2, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=2, shuffle=True)

train_count = len(train_dataset)
valid_count = len(valid_dataset)

print('Train Set- ' + str(len(train_dataset)) + ' images in ' + str(len(train_loader)) +' batches')
print('Validation Set - ' + str(len(valid_dataset)) + ' images in ' + str(len(valid_loader)) + ' batches')
# Out:
# Train Set- 6175 images in 1544 batches
# Validation Set - 1388 images in 347 batches

# %% [markdown]
# Network

# %%
import torchvision.models as models

# %% [markdown]
# Model

# %%
num_classes = 7

# %%
if torch.cuda.is_available():
  torch.backends.cudnn.deterministic = True

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
model= models.alexnet(pretrained=False)
model.classifier = nn.Sequential(
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=9216, out_features=4096, bias=True),
    nn.ReLU(inplace=True),
    nn.Dropout(p=0.5, inplace=False),
    nn.Linear(in_features=4096, out_features=4096, bias=True),
    nn.ReLU(inplace=True),
    nn.Linear(in_features=4096, out_features=7, bias=True)
    )
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
if torch.cuda.is_available():
    model.cuda()

# %% [markdown]
# Trainable Parameters

# %%
total_params = sum(p.numel() for p in model.parameters())
print ("Number of Trainable Parameters -", total_params)
# Out:
# Number of Trainable Parameters - 57032519

# %%
num_epochs = 15
LEARNING_RATE = 0.0001
WEIGHT_DECAY = 0.0001

optimizer=optim.Adam(model.parameters(),lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)
loss_function=nn.CrossEntropyLoss()

# %% [markdown]
# Training

# %%
for epoch in range(num_epochs):
    
    #Evaluation and training on training dataset
    model.train()

    train_accuracy=0.0
    train_loss=0.0
    
    for i, (images,labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
            
        optimizer.zero_grad()
        
        outputs=model(images)

        loss=loss_function(outputs,labels)
        
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        _,prediction=torch.max(outputs.data,1)
        
        train_accuracy+=int(torch.sum(prediction==labels.data))

        
    train_accuracy=train_accuracy/train_count
    train_loss=train_loss/train_count
    
    
    # Evaluation on validation dataset
    model.eval()
    
    valid_accuracy = 0.0
    valid_loss = 0.0

    for i, (images,labels) in enumerate(valid_loader):
        images, labels = images.to(device), labels.to(device)
            
        outputs=model(images)

        loss = loss_function (outputs, labels)
        _,prediction=torch.max(outputs.data,1)
        valid_accuracy += int(torch.sum(prediction == labels.data))
        valid_loss+= loss.item()
        
    valid_accuracy = valid_accuracy/valid_count
    valid_loss = valid_loss/valid_count
        
    print('Epoch: %d Train Accuracy: %.5f Train Loss: %.5f Validation Accuracy: %.5f  Validation Loss: %.5f' % (epoch, train_accuracy, train_loss, valid_accuracy, valid_loss))
# Out:
# Epoch: 0 Train Accuracy: 0.41198 Train Loss: 0.35139 Validation Accuracy: 0.61960  Validation Loss: 0.22548
# Epoch: 1 Train Accuracy: 0.61830 Train Loss: 0.23270 Validation Accuracy: 0.67579  Validation Loss: 0.19950
# Epoch: 2 Train Accuracy: 0.75611 Train Loss: 0.16291 Validation Accuracy: 0.80764  Validation Loss: 0.12753
# Epoch: 3 Train Accuracy: 0.82186 Train Loss: 0.12290 Validation Accuracy: 0.84006  Validation Loss: 0.10652
# Epoch: 4 Train Accuracy: 0.86802 Train Loss: 0.09246 Validation Accuracy: 0.88329  Validation Loss: 0.07938
# Epoch: 5 Train Accuracy: 0.89603 Train Loss: 0.07722 Validation Accuracy: 0.91571  Validation Loss: 0.06258
# Epoch: 6 Train Accuracy: 0.91352 Train Loss: 0.06437 Validation Accuracy: 0.92219  Validation Loss: 0.05353
# Epoch: 7 Train Accuracy: 0.92615 Train Loss: 0.05681 Validation Accuracy: 0.92579  Validation Loss: 0.05437
# Epoch: 8 Train Accuracy: 0.93117 Train Loss: 0.05006 Validation Accuracy: 0.94020  Validation Loss: 0.04297
# Epoch: 9 Train Accuracy: 0.93992 Train Loss: 0.04388 Validation Accuracy: 0.94885  Validation Loss: 0.04429
# Epoch: 10 Train Accuracy: 0.93781 Train Loss: 0.04706 Validation Accuracy: 0.93948  Validation Loss: 0.04882
# Epoch: 11 Train Accuracy: 0.94753 Train Loss: 0.04153 Validation Accuracy: 0.94813  Validation Loss: 0.04050
# Epoch: 12 Train Accuracy: 0.95887 Train Loss: 0.03221 Validation Accuracy: 0.94380  Validation Loss: 0.04474
# Epoch: 13 Train Accuracy: 0.95903 Train Loss: 0.03319 Validation Accuracy: 0.91210  Validation Loss: 0.07480
# Epoch: 14 Train Accuracy: 0.95498 Train Loss: 0.03511 Validation Accuracy: 0.93444  Validation Loss: 0.05216

# %%
#Save the model
save_path = '/content/gdrive/MyDrive/Train-Test-Val/AlexNet-E15'
torch.save(model, save_path)

# %% [markdown]
# Testing

# %%
#Load latest model
save_path = '/content/gdrive/MyDrive/Train-Test-Val/AlexNet-E15'
model = torch.load(save_path)

# %%
#path for testing dataset
dataset_path = '/content/gdrive/MyDrive/Train-Test-Val/test'

# %%
batch_size = 9

# %%
test_dataset = load_dataset(str(dataset_path)).dataset
test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2, shuffle=False)
print('Testing Set - ' + str(len(test_dataset)) + ' images in ' + str(len(test_loader)) + ' batches' )
# Out:
# Testing Set - 2007 images in 223 batches

# %%
model.eval()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=7, bias=True)
#   )
# )

# %%
y_pred = []
y_true = []

# iterate over test data
for i, (images, labels) in enumerate(test_loader):
    images, labels = images.to(device), labels.to(device)

    output = model(images) # Feed Network

    output = (torch.max(torch.exp(output), 1)[1])
    output = output.data.cpu().numpy()

    y_pred.extend(output) # Save Prediction
        
    labels1 = labels.data.cpu().numpy()
    y_true.extend(labels1) # Save Truth

# %% [markdown]
# Metrics

# %%
from sklearn.metrics import classification_report, accuracy_score
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
r = classification_report(y_true, y_pred,zero_division=0,output_dict=True)

# %%
print ('Accuracy - ', r.get ('accuracy'))
print ('Weighted Average - ', r.get('weighted avg'))
print ('Macro Average - ', r.get('macro avg'))
# Out:
# Accuracy -  0.9701046337817638
# Weighted Average -  {'precision': 0.9714698542915108, 'recall': 0.9701046337817638, 'f1-score': 0.9701684402129723, 'support': 2007}
# Macro Average -  {'precision': 0.9703747380620504, 'recall': 0.97081638042347, 'f1-score': 0.9699318950471197, 'support': 2007}

# %% [markdown]
# ROC Curve

# %%
model.eval()
y_test = []
y_score = []

# %%
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs, classes = inputs.to(device), classes.to(device)
        y_test.append(F.one_hot(classes.cpu(), 7).numpy())
        
        try:
            bs, ncrops, c, h, w = inputs.size()
        except:
            bs, c, h, w = inputs.size()
            ncrops = 1
        outputs = model(inputs)
        
        y_score.append(outputs.cpu().numpy())

# %%
y_test = np.array([t.ravel() for t in y_test], dtype='object')
y_score = np.array([t.ravel() for t in y_score], dtype='object')

# %%
y_test = y_test.astype('float')
y_score = y_score.astype('float')

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr = dict()
tpr = dict()
local_roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(np.array(y_test[:, i]),np.array(y_score[:, i]))
    local_roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# %%
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
local_roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(7)]))
# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(7):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# %%
# Finally average it and compute AUC
mean_tpr /= 7
fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
local_roc_auc["macro"] = metrics.auc(fpr["macro"], tpr["macro"])

# %%
import matplotlib.pyplot as plt
import itertools

plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-avg ROC curve (area = {0:0.5f})'
               ''.format(local_roc_auc["micro"]),
         color='deeppink', linewidth=2)
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-avg ROC curve (area = {0:0.5f})'
               ''.format(local_roc_auc["macro"]),
         color='navy', linewidth=2)

plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.savefig('samplefigure', bbox_inches='tight')

# %% [markdown]
# AUC Values

# %%
print ("AUC - MicroAvg: ", local_roc_auc["micro"])
print ("AUC - MacroAvg: ", local_roc_auc["macro"])
# Out:
# AUC - MicroAvg:  0.9982174579637273
# AUC - MacroAvg:  0.9977507894340523
